# %%
import pyspark
from pyspark.sql import SQLContext
from pyspark.sql.functions import year,month,hour, when, col, date_format, to_timestamp, round, coalesce
from pyspark.sql import SparkSession
import pandas as pd

# %%
#sc = pyspark.SparkSession('local', 'test')
sc = pyspark.SparkContext(appName="HW3-Q1")
sqlContext = SQLContext(sc)
# Out:
# C:\Users\baris\anaconda3\lib\site-packages\pyspark\sql\context.py:112: FutureWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   warnings.warn(

# %%
df = sqlContext.read.option("header",True).option("inferSchema",True) \
     .csv("C:\\Users\\baris\\OneDrive\\desktop\\CSE 6242 Project\\pollution_us_2000_2016.csv")

# %%
df=df.withColumn("year",year("Date Local")).withColumn("month",month("Date Local"))

# %%
dfmonth=df.select("State","County","year","month","NO2 Mean")\
.groupBy("State","County","year","month").avg("NO2 Mean")
#not used

# %%
df1=df.select("State","County","year","NO2 Mean","O3 Mean","SO2 Mean")\
.groupBy("State","County","year").avg("NO2 Mean","O3 Mean","SO2 Mean")

# %%
df1p=df1.toPandas()
#df1p.to_csv('df1.csv')

# %%
df1p.head(10)
# Out:
#             State          County  year  avg(NO2 Mean)  avg(O3 Mean)  \
# 0  North Carolina     Mecklenburg  2000      15.374838      0.035220
# 1    Pennsylvania    Philadelphia  2000      25.658679      0.015619
# 2      California   Santa Barbara  2000       5.564645      0.032239
# 3      California         Alameda  2001      23.797468      0.009082
# 4        Missouri     Saint Louis  2000      16.273886      0.027747
# 5        Oklahoma             Kay  2000       6.349260      0.041107
# 6          Kansas            Linn  2000       3.505007      0.032779
# 7      California  San Bernardino  2001      21.618935      0.031323
# 8           Texas          Harris  2000      16.867261      0.019523
# 9        Kentucky            Boyd  2000      14.224822      0.028976
#
#    avg(SO2 Mean)
# 0       3.772487
# 1       5.057226
# 2       0.312900
# 3       1.603314
# 4       3.954189
# 5       1.797291
# 6       0.622463
# 7       1.580996
# 8       6.106436
# 9       6.938418

# %%
df2p=pd.read_csv("C:\\Users\\baris\\OneDrive\\desktop\\CSE 6242 Project\death_data.csv")

# %%
df_all=df1p.sort_values(by=['year'])

# %%
df2p['State']=df2p['State'].map({'AK':'Alaska','AL':'Alabama','AR':'Arkansas','AZ':'Arizona','CA': 'California','CO':'Colorado',\
                                 'CT':'Connecticut','DE':'Delaware','FL':'Florida','GA':'Georgia','HI':'Hawaii','IA':'Iowa',\
                                 'ID':'Idaho','IL': 'Illinois','IN':'Indiana','KS':'Kansas','KY':'Kentucky','LA':'Louisiana', \
                                'MA':'Massachusetts','MD':'Maryland','ME':'Maine','MI':'Michigan','MN':'Minnesota','MO':'Missouri', \
                                'NC':'North Carolina','ND':'North Dakota','NH':'New Hampshire','NJ':'New Jersey','NM':'New Mexico', \
                                'NV':'Nevada','NY':'New York','OH':'Ohio','OK':'Oklahoma','OR':'Oregon','PA':'Pennsylvania' ,\
                                'RI':'Rhode Island','SC':'South Carolina','SD':'South Dakota','TN':'Tennessee','TX':'Texas', \
                                'UT':'Utah','VA':'Virginia','WA':'Washington','WI':'Wisconsin','WY':'Wyoming'})

# %%
df3p=pd.merge(df_all,df2p,how="inner", left_on=['State','County','year'], right_on=['State','County_Name','Year'])

# %%
df3p=df3p.T.drop_duplicates().T

# %%
df3p
# Out:
#                State       County  year avg(NO2 Mean) avg(O3 Mean)  \
# 0     North Carolina  Mecklenburg  2000     15.374838      0.03522
# 1             Kansas    Wyandotte  2000     16.518028     0.025053
# 2           Oklahoma     Cherokee  2000       3.67854     0.034708
# 3           Michigan        Wayne  2000     22.640061      0.02335
# 4       Pennsylvania    Lancaster  2000     11.187757     0.026628
# ...              ...          ...   ...           ...          ...
# 1158         Alabama    Jefferson  2016      9.524873     0.028348
# 1159        New York       Queens  2016     17.874275      0.02405
# 1160      California       Solano  2016       8.40495     0.023891
# 1161        Colorado       Denver  2016      25.17045      0.02121
# 1162    Pennsylvania        Adams  2016      2.225029     0.033816
#
#      avg(SO2 Mean) Population     Area Deaths pollution_death  ... circ_death  \
# 0         3.772487     695454   549.74   4505            3001  ...       1588
# 1         1.378182     157882    155.7   1314             873  ...        431
# 2         0.198155      42521   776.45    228             167  ...        115
# 3         5.415251    2061162   672.26  20218           14479  ...       8499
# 4         2.762724     470658    983.9   4137            3034  ...       1699
# ...            ...        ...      ...    ...             ...  ...        ...
# 1158      0.835118     659521  1123.87   7014            4054  ...       1997
# 1159      0.836166    2333054   177.35  14393           10652  ...       5902
# 1160      0.611533     440207   906.85   3148            2041  ...        899
# 1161      1.140453     693060   154.88   4505            2647  ...       1187
# 1162      0.224754     102180   521.56    878             525  ...        288
#
#      canc_death resp_circ_death   Crude Rate pollution_Crude_Rate  \
# 0          1020            1981   647.778286           431.516678
# 1           288             585   832.267136           552.944604
# 2            37             130    536.20564           392.747113
# 3          4435           10044   980.903005           702.467831
# 4           952            2082   878.982191           644.629434
# ...         ...             ...          ...                  ...
# 1158       1444            2610  1063.499115           614.688539
# 1159       3537            7115   616.916711           456.568944
# 1160        848            1193   715.118115           463.645512
# 1161       1010            1637   650.015872           381.929414
# 1162        141             384   859.267959           513.799178
#
#      resp_Crude_Rate circ_Crude_Rate canc_Crude_Rate resp_circ_Crude_Rate  \
# 0          56.509848      228.340048      146.666782           284.849897
# 1          97.541202      272.988688      182.414715           370.529889
# 2          35.276687      270.454599       87.015827           305.731286
# 3          74.957718      412.340224       215.16989           487.297942
# 4          81.375436      360.983984      202.270013            442.35942
# ...              ...             ...             ...                  ...
# 1158       92.946244      302.795514      218.946781           395.741758
# 1159       51.991938      252.973142      151.603863            304.96508
# 1160       66.786762      204.222105      192.636646           271.008866
# 1161       64.929443      171.269443      145.730528           236.198886
# 1162        93.95185      281.855549      137.991779           375.807399
#
#      population_density
# 0           1265.059846
# 1            1014.01413
# 2             54.763346
# 3             3066.0191
# 4            478.359589
# ...                 ...
# 1158         586.830327
# 1159       13155.083169
# 1160         485.424271
# 1161        4474.819215
# 1162         195.912263
#
# [1163 rows x 21 columns]

# %%
def nit(df,year):
    
    dfyear=df3p[(df3p['year']==year)]  
    df_ten_years=df3p[(df3p['year']>year-11)&(df3p['year']<year)]
    
    dfno2=df_ten_years.groupby(["State","County"]).agg(NO2_tenyears=pd.NamedAgg(column="avg(NO2 Mean)", aggfunc="mean"), SO2_tenyears=pd.NamedAgg(column="avg(SO2 Mean)", aggfunc="mean"), O3_tenyears=pd.NamedAgg(column="avg(O3 Mean)", aggfunc="mean")).reset_index()
    
    df_final=pd.merge(dfyear, dfno2, how="inner", on=['State','County'])
    
    return df_final

# %%
l=[]
for i in range(2010,2017):
    l.append(nit(df3p,i))

# %%
df4p=pd.concat(l,join="inner")

# %%
df4p
# Out:
#            State       County  year avg(NO2 Mean) avg(O3 Mean) avg(SO2 Mean)  \
# 0   North Dakota         Cass  2010      5.418302     0.026455      0.281607
# 1     California     Humboldt  2010      2.634853     0.022844      1.285161
# 2       Arkansas      Pulaski  2010     10.004749      0.02765      1.292494
# 3   Pennsylvania         York  2010     11.458178     0.030882      2.165477
# 4     California  Los Angeles  2010     20.447296     0.022612      0.780942
# ..           ...          ...   ...           ...          ...           ...
# 51       Alabama    Jefferson  2016      9.524873     0.028348      0.835118
# 52      New York       Queens  2016     17.874275      0.02405      0.836166
# 53    California       Solano  2016       8.40495     0.023891      0.611533
# 54      Colorado       Denver  2016      25.17045      0.02121      1.140453
# 55  Pennsylvania        Adams  2016      2.225029     0.033816      0.224754
#
#    Population     Area Deaths pollution_death  ...   Crude Rate  \
# 0      149778   1768.0    732             466  ...    488.72331
# 1      134623  4052.52   1035             639  ...    768.81365
# 2      382748   807.91   3234            2020  ...   844.942364
# 3      434972   910.34   3505            2283  ...   805.798994
# 4     9818605  4752.32  56740           40346  ...     577.8825
# ..        ...      ...    ...             ...  ...          ...
# 51     659521  1123.87   7014            4054  ...  1063.499115
# 52    2333054   177.35  14393           10652  ...   616.916711
# 53     440207   906.85   3148            2041  ...   715.118115
# 54     693060   154.88   4505            2647  ...   650.015872
# 55     102180   521.56    878             525  ...   859.267959
#
#    pollution_Crude_Rate resp_Crude_Rate circ_Crude_Rate canc_Crude_Rate  \
# 0            311.127135        50.07411       162.90777       98.145255
# 1            474.658862        94.33752      228.787057      151.534285
# 2            527.762392       58.785415      267.800224      201.176753
# 3             524.86137       71.268955      244.843346      208.749069
# 4             410.91377       53.398624      212.474175      145.040971
# ..                  ...             ...             ...             ...
# 51           614.688539       92.946244      302.795514      218.946781
# 52           456.568944       51.991938      252.973142      151.603863
# 53           463.645512       66.786762      204.222105      192.636646
# 54           381.929414       64.929443      171.269443      145.730528
# 55           513.799178        93.95185      281.855549      137.991779
#
#    resp_circ_Crude_Rate population_density NO2_tenyears SO2_tenyears  \
# 0             212.98188          84.716063     5.134675     0.230227
# 1            323.124578          33.219577     3.808521     0.203946
# 2            326.585639         473.750789     9.639826     2.217690
# 3            316.112301         477.812685    13.787552     4.373538
# 4              265.8728        2066.065627    27.253926     1.923875
# ..                  ...                ...          ...          ...
# 51           395.741758         586.830327    10.185320     0.982086
# 52            304.96508       13155.083169    20.129922     2.905442
# 53           271.008866         485.424271     9.409483     0.781707
# 54           236.198886        4474.819215    27.105770     2.196415
# 55           375.807399         195.912263     2.896022     0.430587
#
#    O3_tenyears
# 0     0.025016
# 1     0.020634
# 2     0.024706
# 3     0.030389
# 4     0.021813
# ..         ...
# 51    0.020253
# 52    0.022157
# 53    0.023283
# 54    0.020553
# 55    0.029346
#
# [480 rows x 24 columns]

# %%
df4p.to_csv('df3.csv')
